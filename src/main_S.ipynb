# %%
import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.utils import resample

# %% [markdown]
# # Data

# %%
np.random.seed(2)

dataset_size = ["small", "medium", "large", "beta", "alpha"][0]

dataset_info = {
    "small": {
        "dataset_name": "wine",
        "class_name": "Class",
        "drop_fields": []
    },
    "medium": {
        "dataset_name": "breast-cancer-wisconsin",
        "class_name": "Class",
        "drop_fields": ["Sample code number"]
    },
    "large": {
        "dataset_name": "seismic-bumps",
        "class_name": "class",
        "drop_fields": []
    },
    "beta": {
        "dataset_name": "Acoustic_Extinguisher_Fire_Dataset",
        "class_name": "Class",
        "drop_fields": []
    },
    "alpha": {
        "dataset_name": "ThoracicSurgery",
        "class_name": "Risk1Yr",
        "drop_fields": []
    }
}

dataset_name = dataset_info[dataset_size]["dataset_name"]
class_name = dataset_info[dataset_size]["class_name"]
drop_fields = dataset_info[dataset_size]["drop_fields"]

df = pd.read_csv('../data/' + dataset_name + ".csv")
df = df.drop(drop_fields, axis=1)
df = df.iloc[np.random.permutation(len(df))]

if dataset_name == "breast-cancer-wisconsin":
    df[class_name].replace({2: 0, 4: 1}, inplace=True)
    
if dataset_name == "ThoracicSurgery":
    df[class_name].replace({'T': 1, 'F': 0}, inplace=True)

n_cut = int(0.8*len(df))
df_trn = df[:n_cut]
df_tst = df[n_cut:]

if dataset_name == "ThoracicSurgery":
    df_1 = df_trn[df_trn[class_name] == 1]
    df_0 = df_trn[df_trn[class_name] != 1]  
    df_1_upsampled = resample(df_1, random_state=2, n_samples=len(df_0), replace=True)

    df_upsampled = pd.concat([df_1_upsampled, df_0], ignore_index=True)
    df_upsampled = df_upsampled.iloc[np.random.permutation(df_upsampled.index)]
    
    df_0_downsampled = resample(df_0, random_state=20, n_samples=len(df_1), replace=False)
    df_downsampled = pd.concat([df_0_downsampled, df_1], ignore_index=True)
    df_downsampled = df_downsampled.iloc[np.random.permutation(df_downsampled.index)]
    
    # df_trn = df_upsampled
    df_trn = df_downsampled

X_trn = df_trn.drop(class_name, axis=1)
y_trn = df_trn[class_name]

X_tst = df_tst.drop(class_name, axis=1)
y_tst = df_tst[class_name]

# %% [markdown]
# # Random Forest

# %%
from RandomForest_df import RandomForest_df

M = X_trn.shape[1]
CV_dict_params = {'NT': [1, 10, 25, 50, 75, 100],
                  'F': sorted(list(set([1, 3, int(np.log2(M + 1)), int(np.sqrt(M))])))
                  }

best_F, best_NT, best_score = None, None, -1
all_metrics_CV = []

for F_ in CV_dict_params['F']:
    for NT_ in CV_dict_params['NT']:
        all_scores = np.zeros(5)
        N = len(X_trn)
        for run in range(5):
            
            ind_tst_ = np.full(len(X_trn), False)
            ind_tst_[int(N*run/5):int(N*(run+1)/5)] = True
            
            X_trn_, y_trn_ = X_trn[ind_tst_], y_trn[ind_tst_]
            X_tst_, y_tst_ = X_trn[~ind_tst_], y_trn[~ind_tst_]
            
            clf = RandomForest_df(NT=NT_, F=F_)
            clf.fit(X_trn_, y_trn_)
            if dataset_name == "wine":
                all_scores[run] = accuracy_score(clf.predict(X_tst_), y_tst_)
            else:
                all_scores[run] = clf.score(X_tst_, y_tst_)
            
        score_ = all_scores.mean()
        all_metrics_CV.append(score_)
        
        if score_ > best_score:
            best_F, best_NT, best_score = F_, NT_, score_

        if dataset_name == "wine":
            print(f'(F, NT) = {(F_, NT_)} \t--> \t Accuracy = {round(score_, 3)}')
        else:
            print(f'(F, NT) = {(F_, NT_)} \t--> \t F1-Score = {round(score_, 3)}')
        
all_metrics_CV = np.array(all_metrics_CV)
# Out:
# (F, NT) = (1, 1) 	--> 	 Accuracy = 0.736
# (F, NT) = (1, 10) 	--> 	 Accuracy = 0.882
# (F, NT) = (1, 25) 	--> 	 Accuracy = 0.937
# (F, NT) = (1, 50) 	--> 	 Accuracy = 0.944
# (F, NT) = (1, 75) 	--> 	 Accuracy = 0.947
# (F, NT) = (1, 100) 	--> 	 Accuracy = 0.942
# (F, NT) = (3, 1) 	--> 	 Accuracy = 0.757
# (F, NT) = (3, 10) 	--> 	 Accuracy = 0.903
# (F, NT) = (3, 25) 	--> 	 Accuracy = 0.937
# (F, NT) = (3, 50) 	--> 	 Accuracy = 0.949
# (F, NT) = (3, 75) 	--> 	 Accuracy = 0.945
# (F, NT) = (3, 100) 	--> 	 Accuracy = 0.945

# %%
print(f'Best Parameters (F, NT): {(best_F, best_NT)}')
best_RF = RandomForest_df(NT=best_NT, F=best_F)
best_RF.fit(X_trn, y_trn, verbose=3)
# Out:
# Best Parameters (F, NT): (3, 50)
# Feature importance: Index(['Color intensity', 'Flavanoids', 'OD280/OD315 of diluted wines',
#        'Proline', 'Hue', 'Malic acid', 'Alcohol', 'Total phenols', 'Magnesium',
#        'Ash', 'Alcalinity of ash', 'Proanthocyanins', 'Nonflavanoid phenols'],
#       dtype='object')
# RandomForest_df(F=3, NT=50)

# %%
y_trn_hat = best_RF.predict(X_trn)
y_tst_hat = best_RF.predict(X_tst)

# %%
average = "binary"
if dataset_name in ['wine']:
    average = "macro"
print(average)

print(f'Accuracy (test): {round(accuracy_score(y_tst.to_numpy(), y_tst_hat), 3)}')
print(f'Precision (test): {round(precision_score(y_tst.to_numpy(), y_tst_hat, average="macro"), 3)}')
print(f'Recall (test): {round(recall_score(y_tst.to_numpy(), y_tst_hat, average=average), 3)}')
print(f'F1 Score (test): {round(f1_score(y_tst.to_numpy(), y_tst_hat, average=average), 3)}')
print('-'*15)
print(f'Accuracy (train): {round(accuracy_score(y_trn.to_numpy(), y_trn_hat), 3)}')
print(f'Precision (train): {round(precision_score(y_trn.to_numpy(), y_trn_hat, average=average), 3)}')
print(f'Recall (train): {round(recall_score(y_trn.to_numpy(), y_trn_hat, average=average), 3)}')
print(f'F1 Score (train): {round(f1_score(y_trn.to_numpy(), y_trn_hat, average=average), 3)}')
# Out:
# macro
# Accuracy (test): 1.0
# Precision (test): 1.0
# Recall (test): 1.0
# F1 Score (test): 1.0
# ---------------
# Accuracy (train): 1.0
# Precision (train): 1.0
# Recall (train): 1.0
# F1 Score (train): 1.0

# %%
all_importances = []
all_metrics = []

for F_ in CV_dict_params['F']:
    for NT_ in CV_dict_params['NT']:
        clf = RandomForest_df(NT=NT_, F=F_)
        print(f'(F, NT) = {(F_, NT_)}')
        clf.fit(X_trn, y_trn, verbose=3)
        all_importances.append(np.flip(np.argsort(clf.importance)))
        y_tst_hat = clf.predict(X_tst)     
        
        acc = accuracy_score(y_tst.to_numpy(), y_tst_hat)
        prec = precision_score(y_tst.to_numpy(), y_tst_hat, average=average)
        rec = recall_score(y_tst.to_numpy(), y_tst_hat, average=average)
        f1_ = f1_score(y_tst.to_numpy(), y_tst_hat, average=average)
           
        print(f'Accuracy (test): {round(acc, 3)}')
        print(f'Precision (test): {round(prec, 3)}')
        print(f'Recall (test): {round(rec, 3)}')
        print(f'F1 Score (test): {round(f1_, 3)}')
        print('-'*15)
        
        all_metrics.append([acc, prec, rec, f1_])
        
all_importances = np.array(all_importances)
all_metrics = np.array(all_metrics)
# Out:
# (F, NT) = (1, 1)
# Feature importance: Index(['Nonflavanoid phenols', 'Hue', 'Alcalinity of ash', 'Proline',
#        'Proanthocyanins', 'Flavanoids', 'Total phenols', 'Magnesium',
#        'Malic acid', 'OD280/OD315 of diluted wines', 'Color intensity', 'Ash',
#        'Alcohol'],
#       dtype='object')
# Accuracy (test): 0.833
# Precision (test): 0.827
# Recall (test): 0.863
# F1 Score (test): 0.839
# ---------------
# (F, NT) = (1, 10)
# Feature importance: Index(['Nonflavanoid phenols', 'OD280/OD315 of diluted wines', 'Malic acid',
#        'Proline', 'Proanthocyanins', 'Magnesium', 'Flavanoids', 'Ash',
#        'Total phenols', 'Alcohol', 'Hue', 'Alcalinity of ash',
#        'Color intensity'],
#       dtype='object')
# Accuracy (test): 0.944
# Precision (test): 0.954
# Recall (test): 0.954
# F1 Score (test): 0.954
# ---------------
# (F, NT) = (1, 25)
# Feature importance: Index(['Magnesium', 'Hue', 'Proline', 'Proanthocyanins',
#        'Nonflavanoid phenols', 'Alcohol', 'Color intensity', 'Malic acid',
#        'OD280/OD315 of diluted wines', 'Ash', 'Total phenols', 'Flavanoids',
#        'Alcalinity of ash'],
#       dtype='object')
# Accuracy (test): 1.0
# Precision (test): 1.0
# Recall (test): 1.0
# F1 Score (test): 1.0
# ---------------
# (F, NT) = (1, 50)
# Feature importance: Index(['Magnesium', 'Malic acid', 'Alcohol', 'Hue', 'Total phenols',
#        'Flavanoids', 'Proline', 'Proanthocyanins', 'Ash',
#        'Nonflavanoid phenols', 'Color intensity',
#        'OD280/OD315 of diluted wines', 'Alcalinity of ash'],
#       dtype='object')
# Accuracy (test): 1.0
# Precision (test): 1.0
# Recall (test): 1.0
# F1 Score (test): 1.0
# ---------------
# (F, NT) = (1, 75)
# Feature importance: Index(['Malic acid', 'Magnesium', 'Hue', 'Nonflavanoid phenols', 'Flavanoids',
#        'Proline', 'Ash', 'Total phenols', 'Alcohol',
#        'OD280/OD315 of diluted wines', 'Proanthocyanins', 'Color intensity',
#        'Alcalinity of ash'],
#       dtype='object')
# Accuracy (test): 1.0
# Precision (test): 1.0
# Recall (test): 1.0
# F1 Score (test): 1.0
# ---------------
# (F, NT) = (1, 100)
# Feature importance: Index(['Nonflavanoid phenols', 'Malic acid', 'Magnesium', 'Flavanoids',
#        'Proline', 'Hue', 'Ash', 'Total phenols', 'Proanthocyanins',
#        'Alcalinity of ash', 'Alcohol', 'Color intensity',
#        'OD280/OD315 of diluted wines'],
#       dtype='object')
# Accuracy (test): 1.0
# Precision (test): 1.0
# Recall (test): 1.0
# F1 Score (test): 1.0
# ---------------
# (F, NT) = (3, 1)
# Feature importance: Index(['Flavanoids', 'OD280/OD315 of diluted wines', 'Color intensity',
#        'Nonflavanoid phenols', 'Alcalinity of ash', 'Malic acid', 'Alcohol',
#        'Proline', 'Hue', 'Proanthocyanins', 'Total phenols', 'Magnesium',
#        'Ash'],
#       dtype='object')
# Accuracy (test): 0.833
# Precision (test): 0.84
# Recall (test): 0.863
# F1 Score (test): 0.849
# ---------------
# (F, NT) = (3, 10)
# Feature importance: Index(['Flavanoids', 'Color intensity', 'Proline',
#        'OD280/OD315 of diluted wines', 'Magnesium', 'Ash', 'Malic acid',
#        'Alcohol', 'Proanthocyanins', 'Alcalinity of ash', 'Hue',
#        'Total phenols', 'Nonflavanoid phenols'],
#       dtype='object')
# Accuracy (test): 1.0
# Precision (test): 1.0
# Recall (test): 1.0
# F1 Score (test): 1.0
# ---------------
# (F, NT) = (3, 25)
# Feature importance: Index(['Flavanoids', 'Color intensity', 'Proline',
#        'OD280/OD315 of diluted wines', 'Malic acid', 'Magnesium', 'Ash',
#        'Alcohol', 'Hue', 'Alcalinity of ash', 'Proanthocyanins',
#        'Total phenols', 'Nonflavanoid phenols'],
#       dtype='object')
# Accuracy (test): 0.972
# Precision (test): 0.979
# Recall (test): 0.976
# F1 Score (test): 0.977
# ---------------
# (F, NT) = (3, 50)
# Feature importance: Index(['Color intensity', 'Flavanoids', 'OD280/OD315 of diluted wines',
#        'Proline', 'Hue', 'Malic acid', 'Alcohol', 'Total phenols', 'Magnesium',
#        'Ash', 'Alcalinity of ash', 'Proanthocyanins', 'Nonflavanoid phenols'],
#       dtype='object')
# Accuracy (test): 1.0
# Precision (test): 1.0
# Recall (test): 1.0
# F1 Score (test): 1.0
# ---------------
# (F, NT) = (3, 75)
# Feature importance: Index(['Color intensity', 'Flavanoids', 'Proline',
#        'OD280/OD315 of diluted wines', 'Malic acid', 'Alcohol', 'Hue',
#        'Total phenols', 'Magnesium', 'Proanthocyanins', 'Ash',
#        'Alcalinity of ash', 'Nonflavanoid phenols'],
#       dtype='object')
# Accuracy (test): 0.972
# Precision (test): 0.979
# Recall (test): 0.976
# F1 Score (test): 0.977
# ---------------
# (F, NT) = (3, 100)
# Feature importance: Index(['Color intensity', 'Flavanoids', 'Proline',
#        'OD280/OD315 of diluted wines', 'Alcohol', 'Hue', 'Malic acid',
#        'Total phenols', 'Proanthocyanins', 'Magnesium', 'Alcalinity of ash',
#        'Ash', 'Nonflavanoid phenols'],
#       dtype='object')
# Accuracy (test): 0.972
# Precision (test): 0.979
# Recall (test): 0.976
# F1 Score (test): 0.977
# ---------------

# %%
all_metrics[:, 1][np.argmax(all_metrics_CV)]
# Out:
# 1.0

# %%
all_metrics_CV
# Out:
# array([0.73563111, 0.88217668, 0.93670238, 0.94373544, 0.94725974,
#        0.94199658, 0.75711846, 0.90322931, 0.93668685, 0.9489986 ,
#        0.94547431, 0.94547431])

# %%
all_metrics_CV
# Out:
# array([0.73563111, 0.88217668, 0.93670238, 0.94373544, 0.94725974,
#        0.94199658, 0.75711846, 0.90322931, 0.93668685, 0.9489986 ,
#        0.94547431, 0.94547431])

# %%
print(all_metrics.T)
# Out:
# [[0.83333333 0.94444444 1.         1.         1.         1.
#   0.83333333 1.         0.97222222 1.         0.97222222 0.97222222]
#  [0.82702483 0.95396825 1.         1.         1.         1.
#   0.84038462 1.         0.97916667 1.         0.97916667 0.97916667]
#  [0.86349206 0.95396825 1.         1.         1.         1.
#   0.86349206 1.         0.97619048 1.         0.97619048 0.97619048]
#  [0.83928571 0.95396825 1.         1.         1.         1.
#   0.84887794 1.         0.97690163 1.         0.97690163 0.97690163]]

# %%
print(all_metrics_CV.T)
# Out:
# [0.73563111 0.88217668 0.93670238 0.94373544 0.94725974 0.94199658
#  0.75711846 0.90322931 0.93668685 0.9489986  0.94547431 0.94547431]

# %%
from utils.print_latex import print_table

print("IMPORTANCES")
print_table(all_importances.T)
print("-"*15)

print("ACC - PRECISION - RECALL - F1 (TEST)")
print_table(all_metrics.T)
print("-"*15)

print("F1 (CV)")
print_table(all_metrics_CV)
print("-"*15)
# Out:
# IMPORTANCES
# \textbf{\#1} & & 7 & 7 & 4 & 4 & 1 & 7 & 6 & 6 & 6 & 9 & 9 & 9\\
# \hline
# \textbf{\#2} & & 10 & 11 & 10 & 1 & 4 & 1 & 11 & 9 & 9 & 6 & 6 & 6\\
# \hline
# \textbf{\#3} & & 3 & 1 & 12 & 0 & 10 & 4 & 9 & 12 & 12 & 11 & 12 & 12\\
# \hline
# \textbf{\#4} & & 12 & 12 & 8 & 10 & 7 & 6 & 7 & 11 & 11 & 12 & 11 & 11\\
# \hline
# \textbf{\#5} & & 8 & 8 & 7 & 5 & 6 & 12 & 3 & 4 & 1 & 10 & 1 & 0\\
# \hline
# \textbf{\#6} & & 6 & 4 & 0 & 6 & 12 & 10 & 1 & 2 & 4 & 1 & 0 & 10\\
# \hline
# \textbf{\#7} & & 5 & 6 & 9 & 12 & 2 & 2 & 0 & 1 & 2 & 0 & 10 & 1\\
# \hline
# \textbf{\#8} & & 4 & 2 & 1 & 8 & 5 & 5 & 12 & 0 & 0 & 5 & 5 & 5\\
# \hline
# \textbf{\#9} & & 1 & 5 & 11 & 2 & 0 & 8 & 10 & 8 & 10 & 4 & 4 & 8\\
# \hline
# \textbf{\#10} & & 11 & 0 & 2 & 7 & 11 & 3 & 8 & 3 & 3 & 2 & 8 & 4\\
# \hline
# \textbf{\#11} & & 9 & 10 & 5 & 9 & 8 & 0 & 5 & 10 & 8 & 3 & 2 & 3\\
# \hline
# \textbf{\#12} & & 2 & 3 & 6 & 11 & 9 & 9 & 4 & 5 & 5 & 8 & 3 & 2\\
# \hline
# \textbf{\#13} & & 0 & 9 & 3 & 3 & 3 & 11 & 2 & 7 & 7 & 7 & 7 & 7\\
# \hline
#
# ---------------
# ACC - PRECISION - RECALL - F1 (TEST)
# \textbf{\#1} & & 0.833 & 0.944 & 1.0 & 1.0 & 1.0 & 1.0 & 0.833 & 1.0 & 0.972 & 1.0 & 0.972 & 0.972\\
# \hline
# \textbf{\#2} & & 0.827 & 0.954 & 1.0 & 1.0 & 1.0 & 1.0 & 0.84 & 1.0 & 0.979 & 1.0 & 0.979 & 0.979\\
# \hline
# \textbf{\#3} & & 0.863 & 0.954 & 1.0 & 1.0 & 1.0 & 1.0 & 0.863 & 1.0 & 0.976 & 1.0 & 0.976 & 0.976\\
# \hline
# \textbf{\#4} & & 0.839 & 0.954 & 1.0 & 1.0 & 1.0 & 1.0 & 0.849 & 1.0 & 0.977 & 1.0 & 0.977 & 0.977\\
# \hline
#
# ---------------
# F1 (CV)
# \textbf{\#1} & & 0.736 & 0.882 & 0.937 & 0.944 & 0.947 & 0.942 & 0.757 & 0.903 & 0.937 & 0.949 & 0.945 & 0.945\\
#
# ---------------

# %%
from sys import modules
del modules["utils.print_latex"]

# %% [markdown]
# # Decision Tree

# %%
from DecisionForest_df import DecisionForest_df

M = X_trn.shape[1]
CV_dict_params = {'NT': [1, 10, 25, 50, 75, 100],
                  'F': sorted(list(set([int(M/4), int(M/2), int(3*M/4)]))) + [-1]
                  }

best_F, best_NT, best_score = None, None, -1
all_metrics_CV = []

for F_ in CV_dict_params['F']:
    for NT_ in CV_dict_params['NT']:
        all_scores = np.zeros(5)
        N = len(X_trn)
        for run in range(5):
            
            ind_tst_ = np.full(len(X_trn), False)
            ind_tst_[int(N*run/5):int(N*(run+1)/5)] = True
            
            X_trn_, y_trn_ = X_trn[ind_tst_], y_trn[ind_tst_]
            X_tst_, y_tst_ = X_trn[~ind_tst_], y_trn[~ind_tst_]
            
            clf = DecisionForest_df(NT=NT_, F=F_)
            clf.fit(X_trn_, y_trn_)
        
            if dataset_name == "wine":
                all_scores[run] = accuracy_score(clf.predict(X_tst_), y_tst_)
            else:
                all_scores[run] = clf.score(X_tst_, y_tst_)
            
        score_ = all_scores.mean()
        all_metrics_CV.append(score_)
        
        if score_ > best_score:
            best_F, best_NT, best_score = F_, NT_, score_

        if dataset_name == "wine":
            print(f'(F, NT) = {(F_, NT_)} \t--> \t Accuracy = {round(score_, 3)}')
        else:
            print(f'(F, NT) = {(F_, NT_)} \t--> \t F1-Score = {round(score_, 3)}')
        
all_metrics_CV = np.array(all_metrics_CV)
# Out:
# (F, NT) = (3, 1) 	--> 	 Accuracy = 0.731
# (F, NT) = (3, 10) 	--> 	 Accuracy = 0.831
# (F, NT) = (3, 25) 	--> 	 Accuracy = 0.907
# (F, NT) = (3, 50) 	--> 	 Accuracy = 0.935
# (F, NT) = (3, 75) 	--> 	 Accuracy = 0.931
# (F, NT) = (3, 100) 	--> 	 Accuracy = 0.937
# (F, NT) = (6, 1) 	--> 	 Accuracy = 0.75
# (F, NT) = (6, 10) 	--> 	 Accuracy = 0.923
# (F, NT) = (6, 25) 	--> 	 Accuracy = 0.926
# (F, NT) = (6, 50) 	--> 	 Accuracy = 0.919
# (F, NT) = (6, 75) 	--> 	 Accuracy = 0.917
# (F, NT) = (6, 100) 	--> 	 Accuracy = 0.916
# (F, NT) = (9, 1) 	--> 	 Accuracy = 0.828
# (F, NT) = (9, 10) 	--> 	 Accuracy = 0.893
# (F, NT) = (9, 25) 	--> 	 Accuracy = 0.905
# (F, NT) = (9, 50) 	--> 	 Accuracy = 0.893
# (F, NT) = (9, 75) 	--> 	 Accuracy = 0.889
# (F, NT) = (9, 100) 	--> 	 Accuracy = 0.891
# (F, NT) = (-1, 1) 	--> 	 Accuracy = 0.854
# (F, NT) = (-1, 10) 	--> 	 Accuracy = 0.912
# (F, NT) = (-1, 25) 	--> 	 Accuracy = 0.903
# (F, NT) = (-1, 50) 	--> 	 Accuracy = 0.914
# (F, NT) = (-1, 75) 	--> 	 Accuracy = 0.916
# (F, NT) = (-1, 100) 	--> 	 Accuracy = 0.912

# %%
print(f'Best Parameters (F, NT): {(best_F, best_NT)}')
best_DF = DecisionForest_df(NT=best_NT, F=best_F)
best_DF.fit(X_trn, y_trn, verbose=3)
print(np.flip(np.argsort(best_DF.importance)))
# Out:
# Best Parameters (F, NT): (3, 100)
# Feature importance: Index(['Hue', 'Ash', 'Nonflavanoid phenols', 'Alcalinity of ash',
#        'Proanthocyanins', 'Flavanoids', 'Malic acid', 'Color intensity',
#        'Total phenols', 'Magnesium', 'OD280/OD315 of diluted wines', 'Proline',
#        'Alcohol'],
#       dtype='object')
# [10  2  7  3  8  6  1  9  5  4 11 12  0]

# %%
y_trn_hat = best_DF.predict(X_trn)
y_tst_hat = best_DF.predict(X_tst)

# %%
average = "binary"
if dataset_name in ['wine']:
    average = "macro"
print(average)

print(f'Accuracy (test): {round(accuracy_score(y_tst.to_numpy(), y_tst_hat), 3)}')
print(f'Precision (test): {round(precision_score(y_tst.to_numpy(), y_tst_hat, average=average), 3)}')
print(f'Recall (test): {round(recall_score(y_tst.to_numpy(), y_tst_hat, average=average), 3)}')
print(f'F1 Score (test): {round(f1_score(y_tst.to_numpy(), y_tst_hat, average=average), 3)}')
print('-'*15)
print(f'Accuracy (train): {round(accuracy_score(y_trn.to_numpy(), y_trn_hat), 3)}')
print(f'Precision (train): {round(precision_score(y_trn.to_numpy(), y_trn_hat, average=average), 3)}')
print(f'Recall (train): {round(recall_score(y_trn.to_numpy(), y_trn_hat, average=average), 3)}')
print(f'F1 Score (train): {round(f1_score(y_trn.to_numpy(), y_trn_hat, average=average), 3)}')
# Out:
# macro
# Accuracy (test): 0.944
# Precision (test): 0.961
# Recall (test): 0.952
# F1 Score (test): 0.954
# ---------------
# Accuracy (train): 1.0
# Precision (train): 1.0
# Recall (train): 1.0
# F1 Score (train): 1.0

# %%
all_importances = []
all_metrics = []

for F_ in CV_dict_params['F']:
    for NT_ in CV_dict_params['NT']:
        clf = DecisionForest_df(NT=NT_, F=F_)
        print(f'(F, NT) = {(F_, NT_)}')
        clf.fit(X_trn, y_trn, verbose=3)
        y_tst_hat = clf.predict(X_tst)   
        
        all_importances.append(np.flip(np.argsort(clf.importance)))     
        
        acc = accuracy_score(y_tst.to_numpy(), y_tst_hat)
        prec = precision_score(y_tst.to_numpy(), y_tst_hat, average=average)
        rec = recall_score(y_tst.to_numpy(), y_tst_hat, average=average)
        f1_ = f1_score(y_tst.to_numpy(), y_tst_hat, average=average)
           
        print(f'Accuracy (test): {round(acc, 3)}')
        print(f'Precision (test): {round(prec, 3)}')
        print(f'Recall (test): {round(rec, 3)}')
        print(f'F1 Score (test): {round(f1_, 3)}')
        print('-'*15)
        
        all_metrics.append([acc, prec, rec, f1_])
        
all_importances = np.array(all_importances)
all_metrics = np.array(all_metrics)
# Out:
# (F, NT) = (3, 1)
# Feature importance: Index(['OD280/OD315 of diluted wines', 'Flavanoids', 'Magnesium', 'Proline',
#        'Hue', 'Color intensity', 'Proanthocyanins', 'Nonflavanoid phenols',
#        'Total phenols', 'Alcalinity of ash', 'Ash', 'Malic acid', 'Alcohol'],
#       dtype='object')
# Accuracy (test): 0.944
# Precision (test): 0.956
# Recall (test): 0.93
# F1 Score (test): 0.941
# ---------------
# (F, NT) = (3, 10)
# Feature importance: Index(['Ash', 'Hue', 'Magnesium', 'OD280/OD315 of diluted wines', 'Flavanoids',
#        'Nonflavanoid phenols', 'Alcalinity of ash', 'Malic acid',
#        'Proanthocyanins', 'Total phenols', 'Color intensity', 'Alcohol',
#        'Proline'],
#       dtype='object')
# Accuracy (test): 0.944
# Precision (test): 0.954
# Recall (test): 0.954
# F1 Score (test): 0.954
# ---------------
# (F, NT) = (3, 25)
# Feature importance: Index(['Ash', 'Nonflavanoid phenols', 'Alcalinity of ash', 'Malic acid', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline', 'Total phenols',
#        'Proanthocyanins', 'Flavanoids', 'Magnesium', 'Color intensity',
#        'Alcohol'],
#       dtype='object')
# Accuracy (test): 0.944
# Precision (test): 0.961
# Recall (test): 0.952
# F1 Score (test): 0.954
# ---------------
# (F, NT) = (3, 50)
# Feature importance: Index(['Ash', 'Hue', 'Nonflavanoid phenols', 'Malic acid', 'Color intensity',
#        'Alcalinity of ash', 'OD280/OD315 of diluted wines', 'Proanthocyanins',
#        'Proline', 'Flavanoids', 'Magnesium', 'Total phenols', 'Alcohol'],
#       dtype='object')
# Accuracy (test): 0.944
# Precision (test): 0.961
# Recall (test): 0.952
# F1 Score (test): 0.954
# ---------------
# (F, NT) = (3, 75)
# Feature importance: Index(['Ash', 'Hue', 'Alcalinity of ash', 'Flavanoids', 'Malic acid',
#        'Color intensity', 'Nonflavanoid phenols',
#        'OD280/OD315 of diluted wines', 'Magnesium', 'Proanthocyanins',
#        'Proline', 'Total phenols', 'Alcohol'],
#       dtype='object')
# Accuracy (test): 0.944
# Precision (test): 0.961
# Recall (test): 0.952
# F1 Score (test): 0.954
# ---------------
# (F, NT) = (3, 100)
# Feature importance: Index(['Hue', 'Ash', 'Nonflavanoid phenols', 'Alcalinity of ash',
#        'Proanthocyanins', 'Flavanoids', 'Malic acid', 'Color intensity',
#        'Total phenols', 'Magnesium', 'OD280/OD315 of diluted wines', 'Proline',
#        'Alcohol'],
#       dtype='object')
# Accuracy (test): 0.944
# Precision (test): 0.961
# Recall (test): 0.952
# F1 Score (test): 0.954
# ---------------
# (F, NT) = (6, 1)
# Feature importance: Index(['Flavanoids', 'Hue', 'OD280/OD315 of diluted wines', 'Proanthocyanins',
#        'Magnesium', 'Ash', 'Proline', 'Color intensity',
#        'Nonflavanoid phenols', 'Total phenols', 'Alcalinity of ash',
#        'Malic acid', 'Alcohol'],
#       dtype='object')
# Accuracy (test): 0.944
# Precision (test): 0.954
# Recall (test): 0.954
# F1 Score (test): 0.954
# ---------------
# (F, NT) = (6, 10)
# Feature importance: Index(['Hue', 'Ash', 'Flavanoids', 'Magnesium', 'Color intensity',
#        'Malic acid', 'Proline', 'Total phenols',
#        'OD280/OD315 of diluted wines', 'Proanthocyanins', 'Alcalinity of ash',
#        'Alcohol', 'Nonflavanoid phenols'],
#       dtype='object')
# Accuracy (test): 0.972
# Precision (test): 0.979
# Recall (test): 0.976
# F1 Score (test): 0.977
# ---------------
# (F, NT) = (6, 25)
# Feature importance: Index(['Ash', 'Hue', 'Flavanoids', 'Color intensity', 'Proline',
#        'Alcalinity of ash', 'Magnesium', 'Malic acid', 'Proanthocyanins',
#        'OD280/OD315 of diluted wines', 'Total phenols', 'Alcohol',
#        'Nonflavanoid phenols'],
#       dtype='object')
# Accuracy (test): 0.972
# Precision (test): 0.979
# Recall (test): 0.976
# F1 Score (test): 0.977
# ---------------
# (F, NT) = (6, 50)
# Feature importance: Index(['Hue', 'Ash', 'Color intensity', 'Flavanoids', 'Proline', 'Malic acid',
#        'OD280/OD315 of diluted wines', 'Alcalinity of ash', 'Proanthocyanins',
#        'Magnesium', 'Nonflavanoid phenols', 'Total phenols', 'Alcohol'],
#       dtype='object')
# Accuracy (test): 0.972
# Precision (test): 0.979
# Recall (test): 0.976
# F1 Score (test): 0.977
# ---------------
# (F, NT) = (6, 75)
# Feature importance: Index(['Hue', 'Flavanoids', 'Ash', 'Color intensity', 'Proline', 'Malic acid',
#        'OD280/OD315 of diluted wines', 'Alcalinity of ash', 'Magnesium',
#        'Alcohol', 'Proanthocyanins', 'Total phenols', 'Nonflavanoid phenols'],
#       dtype='object')
# Accuracy (test): 0.972
# Precision (test): 0.979
# Recall (test): 0.976
# F1 Score (test): 0.977
# ---------------
# (F, NT) = (6, 100)
# Feature importance: Index(['Hue', 'Flavanoids', 'Color intensity', 'Ash', 'Proline', 'Malic acid',
#        'OD280/OD315 of diluted wines', 'Alcalinity of ash', 'Magnesium',
#        'Alcohol', 'Proanthocyanins', 'Total phenols', 'Nonflavanoid phenols'],
#       dtype='object')
# Accuracy (test): 0.972
# Precision (test): 0.979
# Recall (test): 0.976
# F1 Score (test): 0.977
# ---------------
# (F, NT) = (9, 1)
# Feature importance: Index(['Ash', 'OD280/OD315 of diluted wines', 'Color intensity', 'Flavanoids',
#        'Magnesium', 'Malic acid', 'Proline', 'Hue', 'Proanthocyanins',
#        'Nonflavanoid phenols', 'Total phenols', 'Alcalinity of ash',
#        'Alcohol'],
#       dtype='object')
# Accuracy (test): 0.944
# Precision (test): 0.954
# Recall (test): 0.954
# F1 Score (test): 0.954
# ---------------
# (F, NT) = (9, 10)
# Feature importance: Index(['OD280/OD315 of diluted wines', 'Flavanoids', 'Hue', 'Ash', 'Proline',
#        'Color intensity', 'Magnesium', 'Malic acid', 'Proanthocyanins',
#        'Total phenols', 'Alcalinity of ash', 'Alcohol',
#        'Nonflavanoid phenols'],
#       dtype='object')
# Accuracy (test): 0.944
# Precision (test): 0.961
# Recall (test): 0.952
# F1 Score (test): 0.954
# ---------------
# (F, NT) = (9, 25)
# Feature importance: Index(['Flavanoids', 'Hue', 'Proline', 'OD280/OD315 of diluted wines', 'Ash',
#        'Color intensity', 'Alcohol', 'Magnesium', 'Alcalinity of ash',
#        'Malic acid', 'Total phenols', 'Proanthocyanins',
#        'Nonflavanoid phenols'],
#       dtype='object')
# Accuracy (test): 0.944
# Precision (test): 0.961
# Recall (test): 0.952
# F1 Score (test): 0.954
# ---------------
# (F, NT) = (9, 50)
# Feature importance: Index(['Flavanoids', 'Proline', 'Ash', 'OD280/OD315 of diluted wines', 'Hue',
#        'Color intensity', 'Magnesium', 'Alcohol', 'Alcalinity of ash',
#        'Malic acid', 'Proanthocyanins', 'Total phenols',
#        'Nonflavanoid phenols'],
#       dtype='object')
# Accuracy (test): 0.917
# Precision (test): 0.944
# Recall (test): 0.929
# F1 Score (test): 0.93
# ---------------
# (F, NT) = (9, 75)
# Feature importance: Index(['Flavanoids', 'Proline', 'OD280/OD315 of diluted wines', 'Hue', 'Ash',
#        'Color intensity', 'Magnesium', 'Alcohol', 'Alcalinity of ash',
#        'Malic acid', 'Proanthocyanins', 'Total phenols',
#        'Nonflavanoid phenols'],
#       dtype='object')
# Accuracy (test): 0.917
# Precision (test): 0.944
# Recall (test): 0.929
# F1 Score (test): 0.93
# ---------------
# (F, NT) = (9, 100)
# Feature importance: Index(['Flavanoids', 'OD280/OD315 of diluted wines', 'Proline', 'Ash',
#        'Color intensity', 'Hue', 'Magnesium', 'Alcohol', 'Alcalinity of ash',
#        'Malic acid', 'Proanthocyanins', 'Total phenols',
#        'Nonflavanoid phenols'],
#       dtype='object')
# Accuracy (test): 0.917
# Precision (test): 0.944
# Recall (test): 0.929
# F1 Score (test): 0.93
# ---------------
# (F, NT) = (-1, 1)
# Feature importance: Index(['Proline', 'OD280/OD315 of diluted wines', 'Color intensity',
#        'Flavanoids', 'Alcalinity of ash', 'Ash', 'Hue', 'Proanthocyanins',
#        'Nonflavanoid phenols', 'Total phenols', 'Magnesium', 'Malic acid',
#        'Alcohol'],
#       dtype='object')
# Accuracy (test): 0.917
# Precision (test): 0.944
# Recall (test): 0.929
# F1 Score (test): 0.93
# ---------------
# (F, NT) = (-1, 10)
# Feature importance: Index(['Ash', 'OD280/OD315 of diluted wines', 'Nonflavanoid phenols',
#        'Flavanoids', 'Hue', 'Total phenols', 'Proline', 'Malic acid',
#        'Magnesium', 'Alcalinity of ash', 'Color intensity', 'Alcohol',
#        'Proanthocyanins'],
#       dtype='object')
# Accuracy (test): 0.944
# Precision (test): 0.961
# Recall (test): 0.952
# F1 Score (test): 0.954
# ---------------
# (F, NT) = (-1, 25)
# Feature importance: Index(['Ash', 'OD280/OD315 of diluted wines', 'Hue', 'Malic acid',
#        'Flavanoids', 'Total phenols', 'Color intensity',
#        'Nonflavanoid phenols', 'Alcalinity of ash', 'Proline',
#        'Proanthocyanins', 'Alcohol', 'Magnesium'],
#       dtype='object')
# Accuracy (test): 0.917
# Precision (test): 0.944
# Recall (test): 0.929
# F1 Score (test): 0.93
# ---------------
# (F, NT) = (-1, 50)
# Feature importance: Index(['Ash', 'OD280/OD315 of diluted wines', 'Malic acid', 'Total phenols',
#        'Nonflavanoid phenols', 'Hue', 'Flavanoids', 'Proline',
#        'Color intensity', 'Alcalinity of ash', 'Alcohol', 'Magnesium',
#        'Proanthocyanins'],
#       dtype='object')
# Accuracy (test): 0.944
# Precision (test): 0.961
# Recall (test): 0.952
# F1 Score (test): 0.954
# ---------------
# (F, NT) = (-1, 75)
# Feature importance: Index(['Ash', 'OD280/OD315 of diluted wines', 'Hue', 'Total phenols',
#        'Proline', 'Malic acid', 'Flavanoids', 'Color intensity',
#        'Nonflavanoid phenols', 'Alcohol', 'Alcalinity of ash', 'Magnesium',
#        'Proanthocyanins'],
#       dtype='object')
# Accuracy (test): 0.944
# Precision (test): 0.961
# Recall (test): 0.952
# F1 Score (test): 0.954
# ---------------
# (F, NT) = (-1, 100)
# Feature importance: Index(['Ash', 'OD280/OD315 of diluted wines', 'Proline', 'Hue', 'Flavanoids',
#        'Total phenols', 'Malic acid', 'Color intensity', 'Alcohol',
#        'Nonflavanoid phenols', 'Alcalinity of ash', 'Magnesium',
#        'Proanthocyanins'],
#       dtype='object')
# Accuracy (test): 0.944
# Precision (test): 0.961
# Recall (test): 0.952
# F1 Score (test): 0.954
# ---------------

# %%
print(all_metrics.T)
# Out:
# [[0.94444444 0.94444444 0.94444444 0.94444444 0.94444444 0.94444444
#   0.94444444 0.97222222 0.97222222 0.97222222 0.97222222 0.97222222
#   0.94444444 0.94444444 0.94444444 0.91666667 0.91666667 0.91666667
#   0.91666667 0.94444444 0.91666667 0.94444444 0.94444444 0.94444444]
#  [0.95555556 0.95396825 0.96078431 0.96078431 0.96078431 0.96078431
#   0.95396825 0.97916667 0.97916667 0.97916667 0.97916667 0.97916667
#   0.95396825 0.96078431 0.96078431 0.94444444 0.94444444 0.94444444
#   0.94444444 0.96078431 0.94444444 0.96078431 0.96078431 0.96078431]
#  [0.93015873 0.95396825 0.95238095 0.95238095 0.95238095 0.95238095
#   0.95396825 0.97619048 0.97619048 0.97619048 0.97619048 0.97619048
#   0.95396825 0.95238095 0.95238095 0.92857143 0.92857143 0.92857143
#   0.92857143 0.95238095 0.92857143 0.95238095 0.95238095 0.95238095]
#  [0.9406425  0.95396825 0.95352564 0.95352564 0.95352564 0.95352564
#   0.95396825 0.97690163 0.97690163 0.97690163 0.97690163 0.97690163
#   0.95396825 0.95352564 0.95352564 0.92969697 0.92969697 0.92969697
#   0.92969697 0.95352564 0.92969697 0.95352564 0.95352564 0.95352564]]

# %%
print(all_metrics_CV.T)
# Out:
# [0.73064741 0.83115976 0.90675361 0.93493246 0.93143922 0.93673343
#  0.75006986 0.92255861 0.92609843 0.91903431 0.91729545 0.91552554
#  0.82760441 0.89259432 0.90499922 0.89260984 0.88910107 0.89085546
#  0.85396678 0.91203229 0.90316721 0.91378668 0.91552554 0.91201677]

# %%
from utils.print_latex import print_table

print("IMPORTANCES")
print_table(all_importances.T)
print("-"*15)

print("ACC - PRECISION - RECALL - F1 (TEST)")
print_table(all_metrics.T)
print("-"*15)

print("F1 (CV)")
print_table(all_metrics_CV)
print("-"*15)
# Out:
# IMPORTANCES
# \textbf{\#1} & & 11 & 2 & 2 & 2 & 2 & 10 & 6 & 10 & 2 & 10 & 10 & 10 & 2 & 11 & 6 & 6 & 6 & 6 & 12 & 2 & 2 & 2 & 2 & 2\\
# \hline
# \textbf{\#2} & & 6 & 10 & 7 & 10 & 10 & 2 & 10 & 2 & 10 & 2 & 6 & 6 & 11 & 6 & 10 & 12 & 12 & 11 & 11 & 11 & 11 & 11 & 11 & 11\\
# \hline
# \textbf{\#3} & & 4 & 4 & 3 & 7 & 3 & 7 & 11 & 6 & 6 & 9 & 2 & 9 & 9 & 10 & 12 & 2 & 11 & 12 & 9 & 7 & 10 & 1 & 10 & 12\\
# \hline
# \textbf{\#4} & & 12 & 11 & 1 & 1 & 6 & 3 & 8 & 4 & 9 & 6 & 9 & 2 & 6 & 2 & 11 & 11 & 10 & 2 & 6 & 6 & 1 & 5 & 5 & 10\\
# \hline
# \textbf{\#5} & & 10 & 6 & 10 & 9 & 1 & 8 & 4 & 9 & 12 & 12 & 12 & 12 & 4 & 12 & 2 & 10 & 2 & 9 & 3 & 10 & 6 & 7 & 12 & 6\\
# \hline
# \textbf{\#6} & & 9 & 7 & 11 & 3 & 9 & 6 & 2 & 1 & 3 & 1 & 1 & 1 & 1 & 9 & 9 & 9 & 9 & 10 & 2 & 5 & 5 & 10 & 1 & 5\\
# \hline
# \textbf{\#7} & & 8 & 3 & 12 & 11 & 7 & 1 & 12 & 12 & 4 & 11 & 11 & 11 & 12 & 4 & 0 & 4 & 4 & 4 & 10 & 12 & 9 & 6 & 6 & 1\\
# \hline
# \textbf{\#8} & & 7 & 1 & 5 & 8 & 11 & 9 & 9 & 5 & 1 & 3 & 3 & 3 & 10 & 1 & 4 & 0 & 0 & 0 & 8 & 1 & 7 & 12 & 9 & 9\\
# \hline
# \textbf{\#9} & & 5 & 8 & 8 & 12 & 4 & 5 & 7 & 11 & 8 & 8 & 4 & 4 & 8 & 8 & 3 & 3 & 3 & 3 & 7 & 4 & 3 & 9 & 7 & 0\\
# \hline
# \textbf{\#10} & & 3 & 5 & 6 & 6 & 8 & 4 & 5 & 8 & 11 & 4 & 0 & 0 & 7 & 5 & 1 & 1 & 1 & 1 & 5 & 3 & 12 & 3 & 0 & 7\\
# \hline
# \textbf{\#11} & & 2 & 9 & 4 & 4 & 12 & 11 & 3 & 3 & 5 & 7 & 8 & 8 & 5 & 3 & 5 & 8 & 8 & 8 & 4 & 9 & 8 & 0 & 3 & 3\\
# \hline
# \textbf{\#12} & & 1 & 0 & 9 & 5 & 5 & 12 & 1 & 0 & 0 & 5 & 5 & 5 & 3 & 0 & 8 & 5 & 5 & 5 & 1 & 0 & 0 & 4 & 4 & 4\\
# \hline
# \textbf{\#13} & & 0 & 12 & 0 & 0 & 0 & 0 & 0 & 7 & 7 & 0 & 7 & 7 & 0 & 7 & 7 & 7 & 7 & 7 & 0 & 8 & 4 & 8 & 8 & 8\\
# \hline
#
# ---------------
# ACC - PRECISION - RECALL - F1 (TEST)
# \textbf{\#1} & & 0.944 & 0.944 & 0.944 & 0.944 & 0.944 & 0.944 & 0.944 & 0.972 & 0.972 & 0.972 & 0.972 & 0.972 & 0.944 & 0.944 & 0.944 & 0.917 & 0.917 & 0.917 & 0.917 & 0.944 & 0.917 & 0.944 & 0.944 & 0.944\\
# \hline
# \textbf{\#2} & & 0.956 & 0.954 & 0.961 & 0.961 & 0.961 & 0.961 & 0.954 & 0.979 & 0.979 & 0.979 & 0.979 & 0.979 & 0.954 & 0.961 & 0.961 & 0.944 & 0.944 & 0.944 & 0.944 & 0.961 & 0.944 & 0.961 & 0.961 & 0.961\\
# \hline
# \textbf{\#3} & & 0.93 & 0.954 & 0.952 & 0.952 & 0.952 & 0.952 & 0.954 & 0.976 & 0.976 & 0.976 & 0.976 & 0.976 & 0.954 & 0.952 & 0.952 & 0.929 & 0.929 & 0.929 & 0.929 & 0.952 & 0.929 & 0.952 & 0.952 & 0.952\\
# \hline
# \textbf{\#4} & & 0.941 & 0.954 & 0.954 & 0.954 & 0.954 & 0.954 & 0.954 & 0.977 & 0.977 & 0.977 & 0.977 & 0.977 & 0.954 & 0.954 & 0.954 & 0.93 & 0.93 & 0.93 & 0.93 & 0.954 & 0.93 & 0.954 & 0.954 & 0.954\\
# \hline
#
# ---------------
# F1 (CV)
# \textbf{\#1} & & 0.731 & 0.831 & 0.907 & 0.935 & 0.931 & 0.937 & 0.75 & 0.923 & 0.926 & 0.919 & 0.917 & 0.916 & 0.828 & 0.893 & 0.905 & 0.893 & 0.889 & 0.891 & 0.854 & 0.912 & 0.903 & 0.914 & 0.916 & 0.912\\
#
# ---------------
